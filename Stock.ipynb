# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data-2.csv")
data.head()
# Out:
#   Company        Date Close/Last    Volume     Open       High      Low
# 0    AAPL  07/17/2023    $193.99  50520160  $191.90    $194.32  $191.81
# 1    AAPL  07/14/2023    $190.69  41616240  $190.23  $191.1799  $189.63
# 2    AAPL  07/13/2023    $190.54  41342340  $190.50    $191.19  $189.78
# 3    AAPL  07-12-2023    $189.77  60750250  $189.68    $191.70  $188.47
# 4    AAPL  07-11-2023    $188.08  46638120  $189.16    $189.30  $186.60

# %%
data["Date"]=pd.to_datetime(data["Date"],format="mixed")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25160 entries, 0 to 25159
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Company     25160 non-null  object
#  1   Date        25160 non-null  datetime64[ns]
#  2   Close/Last  25160 non-null  object
#  3   Volume      25160 non-null  int64
#  4   Open        25160 non-null  object
#  5   High        25160 non-null  object
#  6   Low         25160 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
data.head(5)
# Out:
#   Company       Date Close/Last    Volume     Open       High      Low
# 0    AAPL 2023-07-17    $193.99  50520160  $191.90    $194.32  $191.81
# 1    AAPL 2023-07-14    $190.69  41616240  $190.23  $191.1799  $189.63
# 2    AAPL 2023-07-13    $190.54  41342340  $190.50    $191.19  $189.78
# 3    AAPL 2023-07-12    $189.77  60750250  $189.68    $191.70  $188.47
# 4    AAPL 2023-07-11    $188.08  46638120  $189.16    $189.30  $186.60

# %%
data["High"] = data["High"].replace({"\$":""}, regex=True).astype(float)
data["Low"] = data["Low"].replace({"\$":""}, regex=True).astype(float)
data["Close/Last"] = data["Close/Last"].replace({"\$":""}, regex=True).astype(float)
data["Open"] = data["Open"].replace({"\$":""}, regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1655/2452729962.py:1: SyntaxWarning: invalid escape sequence '\$'
#   data["High"] = data["High"].replace({"\$":""}, regex=True).astype(float)
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1655/2452729962.py:2: SyntaxWarning: invalid escape sequence '\$'
#   data["Low"] = data["Low"].replace({"\$":""}, regex=True).astype(float)
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1655/2452729962.py:3: SyntaxWarning: invalid escape sequence '\$'
#   data["Close/Last"] = data["Close/Last"].replace({"\$":""}, regex=True).astype(float)
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1655/2452729962.py:4: SyntaxWarning: invalid escape sequence '\$'
#   data["Open"] = data["Open"].replace({"\$":""}, regex=True).astype(float)

# %%
data.head(5)
# Out:
#   Company       Date  Close/Last    Volume    Open      High     Low
# 0    AAPL 2023-07-17      193.99  50520160  191.90  194.3200  191.81
# 1    AAPL 2023-07-14      190.69  41616240  190.23  191.1799  189.63
# 2    AAPL 2023-07-13      190.54  41342340  190.50  191.1900  189.78
# 3    AAPL 2023-07-12      189.77  60750250  189.68  191.7000  188.47
# 4    AAPL 2023-07-11      188.08  46638120  189.16  189.3000  186.60

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25160 entries, 0 to 25159
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Company     25160 non-null  object
#  1   Date        25160 non-null  datetime64[ns]
#  2   Close/Last  25160 non-null  float64
#  3   Volume      25160 non-null  int64
#  4   Open        25160 non-null  float64
#  5   High        25160 non-null  float64
#  6   Low         25160 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                                 Date    Close/Last        Volume  \
# count                          25160  25160.000000  2.516000e+04
# mean   2018-07-15 16:11:49.697933056    102.455878  5.131764e+07
# min              2013-07-18 00:00:00      1.620000  1.143952e+06
# 25%              2016-01-14 18:00:00     36.567500  1.200394e+07
# 50%              2018-07-16 12:00:00     65.680000  2.672083e+07
# 75%              2021-01-13 06:00:00    134.235025  6.857269e+07
# max              2023-07-17 00:00:00    691.690000  1.065209e+09
# std                              NaN    101.991372  6.399143e+07
#
#                Open          High           Low
# count  25160.000000  25160.000000  25160.000000
# mean     102.430761    103.829305    101.006112
# min        1.620000      1.690000      1.610000
# 25%       36.507500     36.890000     36.128000
# 50%       65.650000     66.486900     64.915500
# 75%      134.320000    136.233525    132.660000
# max      692.350000    700.989400    686.090000
# std      101.996115    103.529523    100.399743

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="Date",y="Close/Last",data=data,color="purple")
plt.title("Close Rate VS Date",fontsize=15)
plt.xlabel("Date",fontsize=12)
plt.ylabel("Close Rate",fontsize=12)
plt.show()

# %%
data['Day'] = data['Date'].dt.day
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# %%
data=data.drop(["Date"],axis=1)

# %%
data.head(5)
# Out:
#   Company  Close/Last    Volume    Open      High     Low  Day  Month  Year
# 0    AAPL      193.99  50520160  191.90  194.3200  191.81   17      7  2023
# 1    AAPL      190.69  41616240  190.23  191.1799  189.63   14      7  2023
# 2    AAPL      190.54  41342340  190.50  191.1900  189.78   13      7  2023
# 3    AAPL      189.77  60750250  189.68  191.7000  188.47   12      7  2023
# 4    AAPL      188.08  46638120  189.16  189.3000  186.60   11      7  2023

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Company"]=le.fit_transform(data["Company"])

# %%
data.head(5)
# Out:
#    Company  Close/Last    Volume    Open      High     Low  Day  Month  Year
# 0        0      193.99  50520160  191.90  194.3200  191.81   17      7  2023
# 1        0      190.69  41616240  190.23  191.1799  189.63   14      7  2023
# 2        0      190.54  41342340  190.50  191.1900  189.78   13      7  2023
# 3        0      189.77  60750250  189.68  191.7000  188.47   12      7  2023
# 4        0      188.08  46638120  189.16  189.3000  186.60   11      7  2023

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=data.drop(["Close/Last"],axis=1)
y=data["Close/Last"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_test,y_pred)
print(acc*100)
# Out:
# 99.9829548311459
